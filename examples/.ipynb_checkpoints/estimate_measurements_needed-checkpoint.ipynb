# %%
##### import mrs_mce.sim  as mms
import mrs_mce.graf as mmg

import numpy as np
import pandas as pd
#from scipy import stats as ss

import matplotlib.pyplot as plt
#from matplotlib.colors import ListedColormap
from matplotlib.colors import LogNorm, Normalize, PowerNorm
import seaborn as sns

import scipy.stats
import statsmodels.stats.power as smp

# %%
def gen(transmitter, conc, sd, runs, conc_abs=False): 
    # Load experiment
    exName="../[0I] meta data/2024-02-06.csv"
    data = pd.read_csv(exName)
    dat_pick = data
    dat_ind = dat_pick["transmitter"]==transmitter
    dat_pick = dat_pick.loc[dat_ind,:]
    # data-sd interpol
    alpha = np.interp(np.log10(sd),np.log10(dat_pick["noise-SD"]), np.log10(dat_pick["corr-data-std"]))
    conc_sd=10**alpha
    # linear fit of slope(noise-sd) for x-value
    x = np.array(dat_pick.iloc[:]["noise-SD"])
    y = np.array(dat_pick.iloc[:]["slope"])
    A = np.vstack([x, np.ones(len(x))]).T
    m, c = np.linalg.lstsq(A, y, rcond=None)[0]
    slope_calc=(sd*m)+c
    if conc_abs:
        conc = np.round(conc,3)
    else:
        conc = np.round(np.array(conc)*in_vivo_conc[transmitter],3)
    # new data gen
    return np.random.normal(loc=conc*slope_calc, scale=conc_sd, size=runs).clip(min=0)

# %%
def gen_stats(transmitter, conc, sd, conc_abs=False):
        # Load experiment
    exName="../[0I] meta data/2024-02-06.csv"
    data = pd.read_csv(exName)
    dat_pick = data
    dat_ind = dat_pick["transmitter"]==transmitter
    dat_pick = dat_pick.loc[dat_ind,:]
    # data-sd interpol
    alpha = np.interp(np.log10(sd),np.log10(dat_pick["noise-SD"]), np.log10(dat_pick["corr-data-std"]))
    conc_sd=10**alpha
    # linear fit of slope(noise-sd) for x-value
    x = np.array(dat_pick.iloc[:]["noise-SD"])
    y = np.array(dat_pick.iloc[:]["slope"])
    A = np.vstack([x, np.ones(len(x))]).T
    m, c = np.linalg.lstsq(A, y, rcond=None)[0]
    slope_calc=(sd*m)+c
    conc = np.round(conc,3)
    return conc*slope_calc, conc_sd

# %%
def get_count(transmitter, conc0, conc1, noise, power):
    c_iv = in_vivo_conc[transmitter]
    c1, sd1 = gen_stats(transmitter, c_iv*conc1, noise)
    c0, sd0 = gen_stats(transmitter, c_iv*conc0, noise)
    if sd0 != sd1:
        print('difference in sds: ',sd0-sd1)
    # assuming sd0=sd1 -> same noise
    power_analysis = smp.TTestIndPower()
    z = power_analysis.solve_power(effect_size=((c1-c0)/sd1), power=power, alpha=0.05)
    #print(type(z))
    if type(z) == np.ndarray:
        if z == [10]:
            sample_size = np.nan
        elif len(s) == 1:
            sample_size = z[0]
    else:
        sample_size = z
    sample_size = np.ceil(sample_size)
    return sample_size

# %%
def s_frame(transmitters, concs, noises, power, conc_change_percent=True):
    results = []
    for t in transmitters:
        for n in noises:
            c0=concs[0]
            for c in concs[1:]:
                for p in power:
                    s = get_count(t, c0, c, n, p)
                    if conc_change_percent:
                        results.append([s, t, int(100*(c-c0)/c0), n, p])
                    else:
                        results.append([s, t, c, n, p])
    df_p = pd.DataFrame(results, columns = ['sample size','transmitter','concentration','noise-SD','p-Value'])
    return df_p

# %%
in_vivo_conc = {'Ala': 0.01048363233361748, 'Asc': 0.17803360327151493, 'Asp': 0.11185588081433033, 'Cr': 0.22006487867006622, 'GABA': 0.11482032461690153, 'GPC': 0.028938541950259255, 'GSH': 0.0957845700123036, 'Glc': 0.012725831136262324, 'Gln': 0.011520128816223139, 'Glu': 0.3730411236058548, 'Ins': 0.36322045702244254, 'Lac': 0.040811411418027924, 'NAA': 0.7231575265478172, 'NAAG': 0.01384629086803541, 'PCho': 0.033452258555036626, 'PCr': 0.24755997785343, 'PE': 0.016897826748190632, 'Scyllo': 0.02002915288940416, 'Tau': 0.11391891776102547, 'mm': 0.3065042074594444, 'gamma_0': 24.49517127663636, 'gamma_1': 0.0, 'sigma_0': 8.837469173512668, 'sigma_1': 9.47002990309896, 'eps_0': 3.2740137733273977, 'eps_1': 8.961104666238835, 'Phi0': -0.1599098071275376, 'Phi1': -0.00017942544301019776, 'B_real_0': -0.4181610418385806, 'B_imag_0': -0.2766915181497494, 'B_real_1': -0.5587266517972203, 'B_imag_1': -0.37293876373452, 'B_real_2': 0.004103790032478799, 'B_imag_2': 1.2087620943441988, 'Cr+PCr': 0.4676248565234962, 'Glu+Gln': 0.38456125242207795, 'GPC+PCho': 0.06239080050529592, 'Glc+Tau': 0.1266447488972878, 'NAA+NAAG': 0.7370038174158525, 'SNR': 117.04177907653084, 'noise_sd': 0.35822073104047186, 'noise_var': 0.14058844750995889, 'PCh': 0.033452258555036626, 'Mac': 0.3065042074594444}
conc_steps=np.array([0.05, 0.2, 0.4, 0.6, 1, 1.5, 1.8, 2, 2.5]) #relative
SDs = [0.01, 0.1, 0.5, 1, 2, 10, 25] # v2:21.Juno, rearr[0. 0.]anged (in vivo : 0.35)
expNameDict = {"NAA":"a", "GABA":"b", "Cr":"c", "Glu":"d"}

# %%
(14.458, 3.736,"pain stimuli")
# Out:
# (14.458, 3.736, 'pain stimuli')

# %%
transmitters=["Glu"]
#concs = [1, 1.01, 1.02, 1.03, 1.04, 1.05, 1.1, 1.25, 2]
noises = [0.35, 0.7, 1]
power = [0.8]#,0.8,0.9]

expect = [
    (6.97, 1.739,"neural activation"), 
    #factors of experimental design may have a large impact on the size of these changes. 
    (4.749, 1.45,"block studies"),
    (13.429, 3.59,"event paradigms"), #"event related paradigms"
    (2.318, 1.227 ,"visual stimuli"), #prolonged visual stimuli
    (14.458, 3.736,"pain stimuli")
    ]
designs = []
concs = []#1]
for e in expect:
    designs.append(e[2])
    
    a = []
    for i in [0,1]:
        a.append(((e[i]/100)))
    a[0]+=1
    rounded = []
    for r in [1, a[0], a[0]+a[1], a[0]-a[1]]:
        rounded.append(np.round(r,4))
    concs.append(rounded)

# %%
df_ar=[]
for n in noises:
    for i in range(len(concs)):
        result = s_frame(transmitters, concs[i], [n], power,conc_change_percent=False)
        df_adv = result.loc[0].copy()
        s = result["sample size"]
        df_adv["concentration"] = 100*(df_adv["concentration"]-1)
        df_adv["pos_abs_err"] = s[2]-s[0]
        df_adv["neg_abs_err"] = s[1]-s[0]
        df_adv["study design"] = expect[i][2]
        df_ar.append(df_adv.copy())
# Out:
# /home/ko/conda/envs/fsl/lib/python3.9/site-packages/statsmodels/stats/power.py:525: ConvergenceWarning:
# Failed to converge on a solution.
#
#   warnings.warn(convergence_doc, ConvergenceWarning)
# /home/ko/conda/envs/fsl/lib/python3.9/site-packages/statsmodels/stats/power.py:525: ConvergenceWarning:
# Failed to converge on a solution.
#
#   warnings.warn(convergence_doc, ConvergenceWarning)
# /home/ko/conda/envs/fsl/lib/python3.9/site-packages/statsmodels/stats/power.py:525: ConvergenceWarning:
# Failed to converge on a solution.
#
#   warnings.warn(convergence_doc, ConvergenceWarning)
# /home/ko/conda/envs/fsl/lib/python3.9/site-packages/statsmodels/stats/power.py:525: ConvergenceWarning:
# Failed to converge on a solution.
#
#   warnings.warn(convergence_doc, ConvergenceWarning)
# /home/ko/conda/envs/fsl/lib/python3.9/site-packages/statsmodels/stats/power.py:525: ConvergenceWarning:
# Failed to converge on a solution.
#
#   warnings.warn(convergence_doc, ConvergenceWarning)
# /home/ko/conda/envs/fsl/lib/python3.9/site-packages/statsmodels/stats/power.py:525: ConvergenceWarning:
# Failed to converge on a solution.
#
#   warnings.warn(convergence_doc, ConvergenceWarning)
# /home/ko/conda/envs/fsl/lib/python3.9/site-packages/statsmodels/stats/power.py:525: ConvergenceWarning:
# Failed to converge on a solution.
#
#   warnings.warn(convergence_doc, ConvergenceWarning)
# /home/ko/conda/envs/fsl/lib/python3.9/site-packages/statsmodels/stats/power.py:525: ConvergenceWarning:
# Failed to converge on a solution.
#
#   warnings.warn(convergence_doc, ConvergenceWarning)
# /home/ko/conda/envs/fsl/lib/python3.9/site-packages/statsmodels/stats/power.py:525: ConvergenceWarning:
# Failed to converge on a solution.
#
#   warnings.warn(convergence_doc, ConvergenceWarning)
# /home/ko/conda/envs/fsl/lib/python3.9/site-packages/statsmodels/stats/power.py:525: ConvergenceWarning:
# Failed to converge on a solution.
#
#   warnings.warn(convergence_doc, ConvergenceWarning)

# %%
df_result = pd.concat(df_ar, axis=1).T
#MultiIndex.from_frame(df, sortorder=None, names=None)
cols = ['transmitter', 'study design', 'noise-SD', 'concentration', 'sample size',
       'pos_abs_err', 'neg_abs_err', 'p-Value']
df_result = df_result[cols + [c for c in df_result.columns if c not in cols]]
del df_result["transmitter"], df_result["p-Value"]

df_result.sort_values(by="study design", inplace=True)
df_result.set_index("study design", inplace=True)
df_result
# Out:
#                   noise-SD concentration sample size pos_abs_err neg_abs_err
# study design
# block studies         0.35          4.75         3.0         1.0         0.0
# block studies          0.7          4.75         6.0         5.0        -2.0
# block studies            1          4.75        10.0        10.0        -3.0
# event paradigms       0.35         13.43         NaN         NaN         NaN
# event paradigms        0.7         13.43         3.0         0.0         NaN
# event paradigms          1         13.43         3.0         1.0         0.0
# neural activation     0.35          6.97         3.0         0.0         NaN
# neural activation      0.7          6.97         4.0         1.0        -1.0
# neural activation        1          6.97         6.0         2.0        -2.0
# pain stimuli          0.35         14.46         NaN         NaN         NaN
# pain stimuli           0.7         14.46         NaN         NaN         NaN
# pain stimuli             1         14.46         3.0         1.0         0.0
# visual stimuli        0.35          2.32         6.0        17.0        -2.0
# visual stimuli         0.7          2.32        18.0        68.0        -8.0
# visual stimuli           1          2.32        35.0       135.0       -18.0

# %%
df_result.to_latex(buf="table", float_format="%.2f")

# %%
#index = pd.MultiIndex.from_frame(df_result)
mindex = pd.MultiIndex.from_product([noises,designs], names=["noise-SD", "study design"])
#del df_result["noise-SD"], df_result['study design']
df_print = pd.DataFrame(df_result, index=mindex)
df_print
# Out:
#                            study design concentration noise-SD sample size  \
# noise-SD study design
# 0.35     neural activation          NaN           NaN      NaN         NaN
#          block studies              NaN           NaN      NaN         NaN
#          event paradigms            NaN           NaN      NaN         NaN
#          visual stimuli             NaN           NaN      NaN         NaN
#          pain stimuli               NaN           NaN      NaN         NaN
# 0.70     neural activation          NaN           NaN      NaN         NaN
#          block studies              NaN           NaN      NaN         NaN
#          event paradigms            NaN           NaN      NaN         NaN
#          visual stimuli             NaN           NaN      NaN         NaN
#          pain stimuli               NaN           NaN      NaN         NaN
# 1.00     neural activation          NaN           NaN      NaN         NaN
#          block studies              NaN           NaN      NaN         NaN
#          event paradigms            NaN           NaN      NaN         NaN
#          visual stimuli             NaN           NaN      NaN         NaN
#          pain stimuli               NaN           NaN      NaN         NaN
#
#                            pos_abs_err neg_abs_err
# noise-SD study design
# 0.35     neural activation         NaN         NaN
#          block studies             NaN         NaN
#          event paradigms           NaN         NaN
#          visual stimuli            NaN         NaN
#          pain stimuli              NaN         NaN
# 0.70     neural activation         NaN         NaN
#          block studies             NaN         NaN
#          event paradigms           NaN         NaN
#          visual stimuli            NaN         NaN
#          pain stimuli              NaN         NaN
# 1.00     neural activation         NaN         NaN
#          block studies             NaN         NaN
#          event paradigms           NaN         NaN
#          visual stimuli            NaN         NaN
#          pain stimuli              NaN         NaN

# %%
mindex = pd.MultiIndex.from_frame(df_result.loc["noise-SD"], names=["noise-SD"])
#del df_result["noise-SD"], df_result['study design']
df_print = pd.DataFrame(df_result.loc["noise-SD"], index=mindex)
df_print
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 mindex = pd.MultiIndex.from_frame(df_result.loc["noise-SD"], names=["noise-SD"])
#       2 #del df_result["noise-SD"], df_result['study design']
#       3 df_print = pd.DataFrame(df_result.loc["noise-SD"], index=mindex)
#
# File ~/conda/envs/fsl/lib/python3.9/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/conda/envs/fsl/lib/python3.9/site-packages/pandas/core/indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File ~/conda/envs/fsl/lib/python3.9/site-packages/pandas/core/indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File ~/conda/envs/fsl/lib/python3.9/site-packages/pandas/core/generic.py:4236, in NDFrame.xs(self, key, axis, level, drop_level)
#    4234             new_index = index[loc]
#    4235 else:
# -> 4236     loc = index.get_loc(key)
#    4238     if isinstance(loc, np.ndarray):
#    4239         if loc.dtype == np.bool_:
#
# File ~/conda/envs/fsl/lib/python3.9/site-packages/pandas/core/indexes/range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# --> 418     raise KeyError(key)
#     419 self._check_indexing_error(key)
#     420 raise KeyError(key)
#
# KeyError: 'noise-SD'

# %%
df_print

# %%
# swap 'runs' and 'p-Value'
dfs_plot = []
fix = ['p-Value', 'noise-SD']
fix_val = [0.8, 0.35]
fix_name=['statistical power','noise-SD']
for i in range(0, len(fix)):
    df_a=df_s.copy()
    dat_ind = df_a[fix[i]]==fix_val[i]
    df_a = df_a.loc[dat_ind,:]
    del df_a[fix[i]]
    df_a = df_a.pivot_table(index="concentration", columns=fix[i-1], values="sample size", dropna=False)
    df_a.sort_values('concentration', ascending=False, inplace=True)
    dfs_plot.append(df_a)

# %%
sns.color_palette("crest")[0]

# %%
fig, axes = plt.subplots(1, 2, squeeze=False, figsize=(12,6*1), sharey='row', sharex='col')
#cmap = ListedColormap(sns.color_palette("viridis", as_cmap=True).colors + [(0.75, 0.75, 0.75)])
cbar_ax = fig.add_axes([.9, 0.15, .03, .7])
black = (0, 0, 0)
palette4 = sns.color_palette("colorblind", 4)
palette7 = [palette4[0], black, black, palette4[1], black, palette4[2], palette4[3]]
linst = "dashed"
linst2 = "dotted"

# original data scatter
vmin = min(dfs_plot[0].dropna().values.min(), dfs_plot[1].dropna().values.min())
vmax = max(dfs_plot[0].dropna().values.max(), dfs_plot[1].dropna().values.max())
for i in range(0, len(dfs_plot)):
    df = dfs_plot[i]
    #df = dfs_plot[i].fillna(-1)
    sns.heatmap(df, ax=axes[0][i], 
            annot=True, fmt="g",
            vmin=vmin, vmax=vmax,
            cmap="crest", norm=LogNorm(),
            cbar=i == 0,
            cbar_ax=None if i else cbar_ax)   
    axes[0][i].set_facecolor(sns.color_palette("crest")[0])
    axes[0][i].set_title('constant '+str(fix_name[i])+' ('+str(fix_val[i])+')',
                         fontsize='medium',
                        loc='left',
                        fontweight='bold',
                        family='monospace')
fig.tight_layout(rect=[0, 0, .9, 1])
plt.subplots_adjust(wspace=0.025, hspace=0.05) #hspace 0.15?????
fig.suptitle('Detecting '+transmitters[0]+' Concentration Changes : Measurements Needed', fontweight='bold', y=1.06)
plt.figtext(.5,1,'number of measurements needed to detect a change, from in vivo concentration',
            ha='center', fontsize='large')

axes[0][0].text(0.05, 0.9, transmitters[0], 
                    ha='left', va='top',
                    transform=axes[0][0].transAxes,
                    fontvariant='small-caps', fontweight='bold',
                    fontsize=60).set_alpha(0.7)

axes[0][0].tick_params(axis='y', labelrotation=0)
axes[0][0].set_ylabel(transmitters[0]+' '+axes[0][0].get_ylabel()+' change [%]',fontweight='bold')
axes[0][0].set_xlabel(axes[0][0].get_xlabel(),fontweight='bold')
axes[0][1].set_xlabel(axes[0][1].get_xlabel(),fontweight='bold')
#axes[0][0].yaxis.set_major_formatter(FormatStrFormatter('+%.0f'))
axes[0][1].set_ylabel('')
axes[0][1].set_xlabel(str(fix_name[0])+' ('+str(fix[0])+')')
plt.savefig('../[0] Plots/['+'8'+'].png',bbox_inches='tight')

# %% [raw]
# Methods
# – demonstrate, example power calc
#
# Results
# – lit: known effectsize –> how many needed
